# %% [markdown]
# # Pillow 를 이용한 Image Processing
#
# ## 연하장 만들기
#
# - ``PIL(Python Image Library)`` 은 ``Pillow`` 의 old name
#
#
#     - 설치는 pip install pillow
#     - 사용은 import PIL

# %%
import sys
import requests
from PIL import Image, ImageFilter, ImageDraw, ImageFont
from io import BytesIO
import base64

url = "https://dimg.donga.com/ugc/CDB/SHINDONGA/Article/5d/c2/67/30/5dc267300fefd2738de6.jpg"

# %%
response = requests.get(url)
img = Image.open(BytesIO(response.content)).resize((350, 470))
img
# Out:
# <PIL.Image.Image image mode=RGB size=350x470 at 0x1A74EE57F28>

# %%
img.save('SeasonsGreeting2022.jpg', 'jpeg')

# %% [markdown]
# ### 흑백 사진으로 변경

# %%
grayscale = img.convert('L')    # L : black and white mode
grayscale
# Out:
# <PIL.Image.Image image mode=L size=350x470 at 0x1A74EDDF5F8>

# %%
cropped = img.crop((100, 100, 350, 350))     # cropping (left, upper, right, lower) pixel coordinates)
cropped
# Out:
# <PIL.Image.Image image mode=RGB size=250x250 at 0x1A74EE1CC88>

# %% [markdown]
# ### Watermark 생성
#
# - 한글 폰트가 필요할 경우 아래 링클를 통해 다운 받을 수 있습니다.
#
# [네이버에서 제공하는 한글 글꼴 링크](https://hangeul.naver.com/font)

# %%
img = Image.open('SeasonsGreeting2022.jpg')
idraw = ImageDraw.Draw(img)
text = '새해복많이 받으세요'
font = ImageFont.truetype("NanumBarunGothic.ttf", size=30)
idraw.text((70, 30), text, font=font, fill=(125,0,125))
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=350x470 at 0x1A74EE5E3C8>

# %%
img.filter(ImageFilter.EMBOSS)
# Out:
# <PIL.Image.Image image mode=RGB size=350x470 at 0x1A74EE5A2B0>

# %%
img.filter(ImageFilter.CONTOUR)
# Out:
# <PIL.Image.Image image mode=RGB size=350x470 at 0x1A74EE5AE80>
